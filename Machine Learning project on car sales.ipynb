# %% [markdown]
# # Machine Learning project on Car_Sales_Dataset

# %% [markdown]
# ## Import the required libraries

# %%
# Import Pandas 
# This library helps us to convert different data files (Structured or semi structured) into pandas dataframe.
import pandas as pd

# Import Numpy
# This library helps us to perform different numerical and statstical operation on different data structure.
import numpy as np

# Import seaborn and matplotlib 
# These both libraries help us to create and visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
# Load the file from local 
df_car_sales_dataset = pd.read_csv("C:/Users/pooja/OneDrive/Documents/codeun/car_sales.csv")

# %%
# Show the first five observation
df_car_sales_dataset.head()
# Out:
#    pv_sales  tw_sales  pv_entry_level_sales  pv_premium_sales  \
# 0   10924.0   89964.0                3402.0            7601.0
# 1    7334.0   65348.0                8475.0            4871.0
# 2   13063.0   33694.0                4776.0            5788.0
# 3   24745.0   23870.0               10805.0            8236.0
# 4    9987.0   64625.0                6203.0           16062.0
#
#    pv_export_sales  tw_export_sales  rural_demand_index  repo_rate  \
# 0           2639.0          21841.0               91.92       5.75
# 1           2561.0           9129.0              134.38       7.00
# 2           4384.0          21110.0               77.44       4.75
# 3           4700.0          23233.0              120.63       6.50
# 4           1318.0           7076.0              104.89       5.75
#
#    inflation_rate  consumer_confidence_index  urban_demand_index  \
# 0            3.71                      89.45              100.49
# ...

# %%
# Show the last five observation
df_car_sales_dataset.tail()
# Out:
#        pv_sales  tw_sales  pv_entry_level_sales  pv_premium_sales  \
# 14995   17112.0   51531.0                3372.0            8103.0
# 14996   22676.0   12725.0               12396.0            5404.0
# 14997   19187.0   41718.0                5040.0            5028.0
# 14998   19749.0   35734.0               10896.0            5533.0
# 14999    7943.0   60112.0                5392.0            6067.0
#
#        pv_export_sales  tw_export_sales  rural_demand_index  repo_rate  \
# 14995           3783.0          20452.0               90.11       7.25
# 14996           2996.0          19824.0              107.99       5.75
# 14997           2676.0          10520.0               89.38       6.00
# 14998           5567.0           9208.0              123.83       4.50
# 14999           3165.0          12755.0              107.86       5.75
#
#        inflation_rate  consumer_confidence_index  urban_demand_index  \
# ...

# %% [markdown]
# ## Basic data overview

# %%
# Check the shape of the data
df_car_sales_dataset.shape
# Out:
# (15000, 19)

# %% [markdown]
# **Inferences**
#  - We have 15000 observations and 19 attributes

# %%
# Check the columns we have in the data
df_car_sales_dataset.columns
# Out:
# Index(['pv_sales', 'tw_sales', 'pv_entry_level_sales', 'pv_premium_sales',
#        'pv_export_sales', 'tw_export_sales', 'rural_demand_index', 'repo_rate',
#        'inflation_rate', 'consumer_confidence_index', 'urban_demand_index',
#        'automaker', 'region', 'vehicle_type', 'inventory_level',
#        'monsoon_index', 'gdp_growth', 'month', 'year'],
#       dtype='object')

# %%
# Check the basic info
df_car_sales_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pv_sales                   15000 non-null  float64
#  1   tw_sales                   15000 non-null  float64
#  2   pv_entry_level_sales       15000 non-null  float64
#  3   pv_premium_sales           15000 non-null  float64
#  4   pv_export_sales            15000 non-null  float64
#  5   tw_export_sales            15000 non-null  float64
#  6   rural_demand_index         15000 non-null  float64
#  7   repo_rate                  15000 non-null  float64
#  8   inflation_rate             15000 non-null  float64
#  9   consumer_confidence_index  15000 non-null  float64
#  10  urban_demand_index         15000 non-null  float64
#  11  automaker                  15000 non-null  object
#  12  region                     15000 non-null  object
# ...

# %% [markdown]
# **Interpretation**
#
#     1. We have 16 numerical columns and 3 categorical columns.
#     2. The data we have, it acquires 2.2+ MB storage space.
#     3. We don't have valid null records in the data.

# %%
# Describe the dataset
df_car_sales_dataset.describe().T
# Out:
#                              count          mean           std      min  \
# pv_sales                   15000.0  14569.956133   7066.737575     0.00
# tw_sales                   15000.0  50058.549067  24827.890076     0.00
# pv_entry_level_sales       15000.0   9179.187067   4105.343816     0.00
# pv_premium_sales           15000.0   6937.227467   2749.382718     0.00
# pv_export_sales            15000.0   3157.745867   1328.324099     0.00
# tw_export_sales            15000.0  15510.033933   6362.774814     0.00
# rural_demand_index         15000.0     99.155852     15.126526    39.95
# repo_rate                  15000.0      5.956100      1.177433     4.00
# inflation_rate             15000.0      4.997885      1.730155     2.00
# consumer_confidence_index  15000.0     99.918431     14.833949    41.74
# urban_demand_index         15000.0    100.053356     14.987341    33.79
# inventory_level            15000.0     19.148600      7.117417     0.00
# ...

# %% [markdown]
# **Interpretation**
#  - From this we can easily indentify the outliers by looking at the difference between mean and 50 percentage (Median).

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Null value handling

# %%
# Check the count of null records present in dataframe

df_car_sales_dataset.isnull().sum()
# Out:
# pv_sales                     0
# tw_sales                     0
# pv_entry_level_sales         0
# pv_premium_sales             0
# pv_export_sales              0
# tw_export_sales              0
# rural_demand_index           0
# repo_rate                    0
# inflation_rate               0
# consumer_confidence_index    0
# urban_demand_index           0
# automaker                    0
# region                       0
# vehicle_type                 0
# inventory_level              0
# monsoon_index                0
# gdp_growth                   0
# month                        0
# year                         0
# dtype: int64

# %% [markdown]
# **Interpretation**
#  - In the data we don't have the null records.

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
# Step-1: seggregate the data based on data type.
df_num = df_car_sales_dataset.select_dtypes(include = 'number')

# %%
# Make a seperate dataframe for categorical columns.
df_cat = df_car_sales_dataset.select_dtypes(include = 'object')

# %%
# Check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['automaker', 'region', 'vehicle_type'], dtype='object')

# %%
df_cat.automaker.value_counts()
# Out:
# automaker
# Suzuki Motorcycle    1114
# Royal Enfield        1111
# Bajaj Auto           1102
# Renault              1094
# Honda                1093
# Yamaha               1084
# Tata Motors          1083
# Mahindra             1078
# Hyundai              1069
# Toyota               1056
# TVS Motor            1043
# Kia                  1035
# Hero MotoCorp        1030
# Maruti Suzuki        1008
# Name: count, dtype: int64

# %%
df_cat.region.value_counts()
# Out:
# region
# Assam                                   457
# Tripura                                 441
# Andaman & Nicobar                       440
# Karnataka                               438
# Telangana                               432
# West Bengal                             431
# Madhya Pradesh                          429
# Punjab                                  429
# Nagaland                                428
# Chhattisgarh                            427
# Mizoram                                 427
# Jharkhand                               426
# Goa                                     422
# Lakshadweep                             422
# Gujarat                                 422
# Haryana                                 420
# Tamil Nadu                              419
# Maharashtra                             418
# Kerala                                  416
# Bihar                                   413
# Dadra & Nagar Haveli and Daman & Diu    412
# ...

# %%
df_cat.vehicle_type.value_counts()
# Out:
# vehicle_type
# Two-Wheeler          7526
# Passenger Vehicle    7474
# Name: count, dtype: int64
